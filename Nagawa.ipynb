# %% [markdown]
# <a href="https://colab.research.google.com/github/shohdy-source/Machine-Learing-Deep-Learning-/blob/main/Nagawa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-96839409-bc11-407f-a47c-bad7232e0235" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96839409-bc11-407f-a47c-bad7232e0235">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 969140360237.explainer.xml to 969140360237.explainer.xml
# User uploaded file "969140360237.explainer.xml" with length 32649 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('969140360237.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df = pd.DataFrame(data).T  # Write in DF and transpose it
df.columns = cols  # Update column names
print(df)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to solve ...
# 1   None  ...                                   Recall that the
# 2   None  ...                                           \n
# 3   None  ...  Let us also recap how to plot the graph of an ...
# 4   None  ...                                               None
# 5   None  ...  Then, we can plot the coordinates on the Carte...
# 6   None  ...                                               None
# 7   None  ...  Being able to apply the definition of the abso...
# 8   None  ...  Let us now introduce the concept of absolute v...
# 9   None  ...                             Consider the equation
# 10  None  ...  Before we look at this algebraically, it can o...
# 11  None  ...                                               None
# 12  None  ...                                               None
# 13  None  ...  From this graph, we can see that the two lines...
# 14  None  ...                                               None
# 15  None  ...                  So, the solution to the equation
# 16  None  ...  Now, we can also see from the graph how we mig...
# 17  None  ...                                                As
# 18  None  ...                          We start with\n
# 19  None  ...                      Then, we look at \n
# 20  None  ...  Combining these two equations, we can see that...
# 21  None  ...  An alternative algebraic method, as opposed to...
# 22  None  ...                                  In this example,
# 23  None  ...  Subtracting 1 from both sides of both equation...
# 24  None  ...          This method can be summarized as follows.
# 25  None  ...                                           \n
# 26  None  ...  The two methods are equivalent, and while we c...
# 27  None  ...  We will now solve a variety of absolute value ...
# 28  None  ...                                           \n
# 29  None  ...                                           \n
# 30  None  ...  The remaining examples in this explainer will ...
# 31  None  ...                                           \n
# 32  None  ...                                           \n
# 33  None  ...                                           \n
# 34  None  ...                                           \n
# 35  None  ...                                           \n
# 36  None  ...  We will finish this explainer by recapping som...
# 37  None  ...                                           \n
#
# [38 rows x 7 columns]

# %%
print (list(df.columns))
# Out:
# ['title', 'seo_meta_description', 'source_id', 'developer_name', 'developer_email', 'dictionary', 'body']

# %%
df
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to solve ...
# 1   None  ...                                   Recall that the
# 2   None  ...                                           \n
# 3   None  ...  Let us also recap how to plot the graph of an ...
# 4   None  ...                                               None
# 5   None  ...  Then, we can plot the coordinates on the Carte...
# 6   None  ...                                               None
# 7   None  ...  Being able to apply the definition of the abso...
# 8   None  ...  Let us now introduce the concept of absolute v...
# 9   None  ...                             Consider the equation
# 10  None  ...  Before we look at this algebraically, it can o...
# 11  None  ...                                               None
# 12  None  ...                                               None
# 13  None  ...  From this graph, we can see that the two lines...
# 14  None  ...                                               None
# 15  None  ...                  So, the solution to the equation
# 16  None  ...  Now, we can also see from the graph how we mig...
# 17  None  ...                                                As
# 18  None  ...                          We start with\n
# 19  None  ...                      Then, we look at \n
# 20  None  ...  Combining these two equations, we can see that...
# 21  None  ...  An alternative algebraic method, as opposed to...
# 22  None  ...                                  In this example,
# 23  None  ...  Subtracting 1 from both sides of both equation...
# 24  None  ...          This method can be summarized as follows.
# 25  None  ...                                           \n
# 26  None  ...  The two methods are equivalent, and while we c...
# 27  None  ...  We will now solve a variety of absolute value ...
# 28  None  ...                                           \n
# 29  None  ...                                           \n
# 30  None  ...  The remaining examples in this explainer will ...
# 31  None  ...                                           \n
# 32  None  ...                                           \n
# 33  None  ...                                           \n
# 34  None  ...                                           \n
# 35  None  ...                                           \n
# 36  None  ...  We will finish this explainer by recapping som...
# 37  None  ...                                           \n
#
# [38 rows x 7 columns]

# %%
df[['source_id']]
# Out:
#    source_id
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
# 30      None
# 31      None
# 32      None
# 33      None
# 34      None
# 35      None
# 36      None
# 37      None

# %%
df[['seo_meta_description']]
# Out:
#    seo_meta_description
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10                 None
# 11                 None
# 12                 None
# 13                 None
# 14                 None
# 15                 None
# 16                 None
# 17                 None
# 18                 None
# 19                 None
# 20                 None
# 21                 None
# 22                 None
# 23                 None
# 24                 None
# 25                 None
# 26                 None
# 27                 None
# 28                 None
# 29                 None
# 30                 None
# 31                 None
# 32                 None
# 33                 None
# 34                 None
# 35                 None
# 36                 None
# 37                 None

# %%
df[['seo_meta_description']]
# Out:
#    seo_meta_description
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10                 None
# 11                 None
# 12                 None
# 13                 None
# 14                 None
# 15                 None
# 16                 None
# 17                 None
# 18                 None
# 19                 None
# 20                 None
# 21                 None
# 22                 None
# 23                 None
# 24                 None
# 25                 None
# 26                 None
# 27                 None
# 28                 None
# 29                 None
# 30                 None
# 31                 None
# 32                 None
# 33                 None
# 34                 None
# 35                 None
# 36                 None
# 37                 None

# %%
df[['developer_name']]
# Out:
#    developer_name
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# 30           None
# 31           None
# 32           None
# 33           None
# 34           None
# 35           None
# 36           None
# 37           None

# %%
df[['title']]
# Out:
#    title
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
# 20  None
# 21  None
# 22  None
# 23  None
# 24  None
# 25  None
# 26  None
# 27  None
# 28  None
# 29  None
# 30  None
# 31  None
# 32  None
# 33  None
# 34  None
# 35  None
# 36  None
# 37  None

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-2b9f3dd6-4b67-414a-8db9-8ca69795dbf3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2b9f3dd6-4b67-414a-8db9-8ca69795dbf3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 972198025105.explainer.xml to 972198025105.explainer.xml
# User uploaded file "972198025105.explainer.xml" with length 22937 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df1 = pd.DataFrame(data).T  # Write in DF and transpose it
df1.columns = cols  # Update column names
print(df1)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df1
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-08a138a2-5c23-40ff-a1e3-303b67d5444b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08a138a2-5c23-40ff-a1e3-303b67d5444b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 973130769145.explainer.xml to 973130769145.explainer.xml
# User uploaded file "973130769145.explainer.xml" with length 25523 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df2 = pd.DataFrame(data).T  # Write in DF and transpose it
df2.columns = cols  # Update column names
print(df2)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df2
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e4757457-1d74-47af-8b8b-b2bf2938265c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e4757457-1d74-47af-8b8b-b2bf2938265c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 973145156531.explainer.xml to 973145156531.explainer.xml
# User uploaded file "973145156531.explainer.xml" with length 22774 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df3 = pd.DataFrame(data).T  # Write in DF and transpose it
df3.columns = cols  # Update column names
print(df3)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df3
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-8ad78b7a-5688-416b-a97e-adedd2b0c1a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ad78b7a-5688-416b-a97e-adedd2b0c1a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 974125905106.explainer.xml to 974125905106.explainer.xml
# User uploaded file "974125905106.explainer.xml" with length 26602 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df4 = pd.DataFrame(data).T  # Write in DF and transpose it
df4.columns = cols  # Update column names
print(df4)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df4
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-b2fff9c6-95d8-4946-9a68-561c6c59c54f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2fff9c6-95d8-4946-9a68-561c6c59c54f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 979165921053.explainer.xml to 979165921053.explainer.xml
# User uploaded file "979165921053.explainer.xml" with length 27956 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df5 = pd.DataFrame(data).T  # Write in DF and transpose it
df5.columns = cols  # Update column names
print(df5)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df5
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-34b53a1a-ff9b-4489-b0fe-c66de65e5305" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34b53a1a-ff9b-4489-b0fe-c66de65e5305">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 980162532502.explainer.xml to 980162532502.explainer.xml
# User uploaded file "980162532502.explainer.xml" with length 34159 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df6 = pd.DataFrame(data).T  # Write in DF and transpose it
df6.columns = cols  # Update column names
print(df6)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df6
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-bf9df522-23ac-4e88-9dbd-2e49b003f939" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf9df522-23ac-4e88-9dbd-2e49b003f939">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 985161036067.explainer.xml to 985161036067.explainer.xml
# User uploaded file "985161036067.explainer.xml" with length 19996 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df7 = pd.DataFrame(data).T  # Write in DF and transpose it
df7.columns = cols  # Update column names
print(df7)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df7
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-9ebb4567-bf9f-4dae-baad-3c86a6c40819" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9ebb4567-bf9f-4dae-baad-3c86a6c40819">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 985195836913.explainer.xml to 985195836913.explainer.xml
# User uploaded file "985195836913.explainer.xml" with length 28418 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df8 = pd.DataFrame(data).T  # Write in DF and transpose it
df8.columns = cols  # Update column names
print(df8)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df8
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-16185e4c-18fc-4df5-9af5-6bb796c4d9ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16185e4c-18fc-4df5-9af5-6bb796c4d9ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 989130863985.explainer.xml to 989130863985.explainer.xml
# User uploaded file "989130863985.explainer.xml" with length 24995 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df9 = pd.DataFrame(data).T  # Write in DF and transpose it
df9.columns = cols  # Update column names
print(df9)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]

# %%
df9
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# 16  None  ...  Close inspection of the main scale of the cali...
# 17  None  ...  The following figure shows where the main scal...
# 18  None  ...
# 19  None  ...  The vernier scale consists of 10 marks. Each m...
# 20  None  ...  The best aligned mark corresponds to a value b...
# 21  None  ...  Let us now look at an example in which a verni...
# 22  None  ...                                           \n
# 23  None  ...  Another length-measuring device that can measu...
# 24  None  ...  Perhaps unhelpfully, the name of this instrume...
# 25  None  ...  The following figure shows a micrometer and th...
# 26  None  ...
# 27  None  ...  The object that the length of is to be measure...
# 28  None  ...  When the thimble is turned, it moves along the...
# 29  None  ...  Let us now look at an example in which a \n   ...
# 30  None  ...                                           \n
# 31  None  ...  Let us now look at an example involving compar...
# 32  None  ...                                           \n
# 33  None  ...  Let us now look at an example that involves ot...
# 34  None  ...                                           \n
# 35  None  ...  Mass is an SI base quantity. Mass is often con...
# 36  None  ...   Measuring devices that give readings in \n
# 37  None  ...  Supposing that such a device was taken to the ...
# 38  None  ...  Tools that measure weight can be calibrated to...
# 39  None  ...  A tool that can measure weight is shown in the...
# 40  None  ...
# 41  None  ...  The action of the weight of a measured object ...
# 42  None  ...  Another such tool is shown in the following fi...
# 43  None  ...
# 44  None  ...  For a pan balance, two weights act, one on eac...
# 45  None  ...  Let us now look at an example involving such t...
# 46  None  ...                                           \n
# 47  None  ...  Let us now summarize what has been learned in ...
# 48  None  ...                                           \n
#
# [49 rows x 6 columns]
