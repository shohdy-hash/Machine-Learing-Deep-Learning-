# %% [markdown]
# <a href="https://colab.research.google.com/github/shohdy-source/Machine-Learing-Deep-Learning-/blob/main/RE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-8483e43e-4116-4617-b553-5ef5c40b7178" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8483e43e-4116-4617-b553-5ef5c40b7178">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 969140360237.explainer.xml to 969140360237.explainer.xml
# User uploaded file "969140360237.explainer.xml" with length 32649 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('969140360237.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df = pd.DataFrame(data).T  # Write in DF and transpose it
df.columns = cols  # Update column names
print(df)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to solve ...
# 1   None  ...                                   Recall that the
# 2   None  ...                                           \n
# 3   None  ...  Let us also recap how to plot the graph of an ...
# 4   None  ...                                               None
# 5   None  ...  Then, we can plot the coordinates on the Carte...
# 6   None  ...                                               None
# 7   None  ...  Being able to apply the definition of the abso...
# 8   None  ...  Let us now introduce the concept of absolute v...
# 9   None  ...                             Consider the equation
# 10  None  ...  Before we look at this algebraically, it can o...
# 11  None  ...                                               None
# 12  None  ...                                               None
# 13  None  ...  From this graph, we can see that the two lines...
# ...

# %%
df
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to solve ...
# 1   None  ...                                   Recall that the
# 2   None  ...                                           \n
# 3   None  ...  Let us also recap how to plot the graph of an ...
# 4   None  ...                                               None
# 5   None  ...  Then, we can plot the coordinates on the Carte...
# 6   None  ...                                               None
# 7   None  ...  Being able to apply the definition of the abso...
# 8   None  ...  Let us now introduce the concept of absolute v...
# 9   None  ...                             Consider the equation
# 10  None  ...  Before we look at this algebraically, it can o...
# 11  None  ...                                               None
# 12  None  ...                                               None
# 13  None  ...  From this graph, we can see that the two lines...
# ...

# %%
f=df[['title', 'seo_meta_description', 'source_id', 'developer_name']]

# %%
f
# Out:
#    title seo_meta_description source_id developer_name
# 0   None                 None      None           None
# 1   None                 None      None           None
# 2   None                 None      None           None
# 3   None                 None      None           None
# 4   None                 None      None           None
# 5   None                 None      None           None
# 6   None                 None      None           None
# 7   None                 None      None           None
# 8   None                 None      None           None
# 9   None                 None      None           None
# 10  None                 None      None           None
# 11  None                 None      None           None
# 12  None                 None      None           None
# 13  None                 None      None           None
# 14  None                 None      None           None
# 15  None                 None      None           None
# ...

# %%
f=f.rename(columns={'title':'explainer id/name'})

# %%
f
# Out:
#    explainer id/name seo_meta_description source_id developer_name
# 0               None                 None      None           None
# 1               None                 None      None           None
# 2               None                 None      None           None
# 3               None                 None      None           None
# 4               None                 None      None           None
# 5               None                 None      None           None
# 6               None                 None      None           None
# 7               None                 None      None           None
# 8               None                 None      None           None
# 9               None                 None      None           None
# 10              None                 None      None           None
# 11              None                 None      None           None
# 12              None                 None      None           None
# ...

# %%
print (list(df.columns))
# Out:
# ['title', 'seo_meta_description', 'source_id', 'developer_name', 'developer_email', 'dictionary', 'body']

# %%
df[['source_id']]
# Out:
#    source_id
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None
# 22      None
# 23      None
# 24      None
# 25      None
# 26      None
# 27      None
# 28      None
# 29      None
# 30      None
# 31      None
# 32      None
# 33      None
# 34      None
# 35      None
# 36      None
# 37      None

# %%
df[['seo_meta_description']]
# Out:
#    seo_meta_description
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10                 None
# 11                 None
# 12                 None
# 13                 None
# 14                 None
# 15                 None
# 16                 None
# 17                 None
# 18                 None
# 19                 None
# 20                 None
# 21                 None
# 22                 None
# 23                 None
# 24                 None
# 25                 None
# 26                 None
# 27                 None
# 28                 None
# 29                 None
# 30                 None
# 31                 None
# 32                 None
# 33                 None
# 34                 None
# 35                 None
# 36                 None
# ...

# %%
df[['seo_meta_description']]
# Out:
#    seo_meta_description
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# 10                 None
# 11                 None
# 12                 None
# 13                 None
# 14                 None
# 15                 None
# 16                 None
# 17                 None
# 18                 None
# 19                 None
# 20                 None
# 21                 None
# 22                 None
# 23                 None
# 24                 None
# 25                 None
# 26                 None
# 27                 None
# 28                 None
# 29                 None
# 30                 None
# 31                 None
# 32                 None
# 33                 None
# 34                 None
# 35                 None
# 36                 None
# ...

# %%
df[['developer_name']]
# Out:
#    developer_name
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# 30           None
# 31           None
# 32           None
# 33           None
# 34           None
# 35           None
# 36           None
# 37           None

# %%
df[['title']]
# Out:
#    title
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
# 20  None
# 21  None
# 22  None
# 23  None
# 24  None
# 25  None
# 26  None
# 27  None
# 28  None
# 29  None
# 30  None
# 31  None
# 32  None
# 33  None
# 34  None
# 35  None
# 36  None
# 37  None

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a329dba9-1ec4-42b1-b8da-36e1bcc2126a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a329dba9-1ec4-42b1-b8da-36e1bcc2126a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 972198025105.explainer.xml to 972198025105.explainer.xml
# User uploaded file "972198025105.explainer.xml" with length 22937 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df1 = pd.DataFrame(data).T  # Write in DF and transpose it
df1.columns = cols  # Update column names
print(df1)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# ...

# %%
df1
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# ...

# %%
    ##p = p.reindex(columns=['1Sun', '2Mon', '3Tue', '4Wed', '5Thu', '6Fri', '7Sat'])
f1=df1.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f1
# Out:
#    title seo_meta_description  source_id developer_name
# 0   None                 None        NaN           None
# 1   None                 None        NaN           None
# 2   None                 None        NaN           None
# 3   None                 None        NaN           None
# 4   None                 None        NaN           None
# 5   None                 None        NaN           None
# 6   None                 None        NaN           None
# 7   None                 None        NaN           None
# 8   None                 None        NaN           None
# 9   None                 None        NaN           None
# 10  None                 None        NaN           None
# 11  None                 None        NaN           None
# 12  None                 None        NaN           None
# 13  None                 None        NaN           None
# 14  None                 None        NaN           None
# 15  None                 None        NaN           None
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-719dae6a-16e5-47e2-b60b-0cd54344342f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-719dae6a-16e5-47e2-b60b-0cd54344342f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 973130769145.explainer.xml to 973130769145.explainer.xml
# User uploaded file "973130769145.explainer.xml" with length 25523 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('973130769145.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df2 = pd.DataFrame(data).T  # Write in DF and transpose it
df2.columns = cols  # Update column names
print(df2)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to connec...
# 1   None  ...  The derivatives of a function give us many dif...
# 2   None  ...                     For a differentiable function
# 3   None  ...                                               None
# 4   None  ...  This is not the only information we can see fr...
# 5   None  ...                                               None
# 6   None  ...               This means we can analyze the curve
# 7   None  ...                                      We know when
# 8   None  ...  We can also do this with the second derivative...
# 9   None  ...                                           \n
# 10  None  ...                                   If our function
# 11  None  ...                                           \n
# 12  None  ...  The concavity of a curve may change at values of
# 13  None  ...                        Let’s start with the curve
# ...

# %%
df2
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to connec...
# 1   None  ...  The derivatives of a function give us many dif...
# 2   None  ...                     For a differentiable function
# 3   None  ...                                               None
# 4   None  ...  This is not the only information we can see fr...
# 5   None  ...                                               None
# 6   None  ...               This means we can analyze the curve
# 7   None  ...                                      We know when
# 8   None  ...  We can also do this with the second derivative...
# 9   None  ...                                           \n
# 10  None  ...                                   If our function
# 11  None  ...                                           \n
# 12  None  ...  The concavity of a curve may change at values of
# 13  None  ...                        Let’s start with the curve
# ...

# %%
f2=df2.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f2
# Out:
#    title seo_meta_description source_id developer_name
# 0   None                 None      None           None
# 1   None                 None      None           None
# 2   None                 None      None           None
# 3   None                 None      None           None
# 4   None                 None      None           None
# 5   None                 None      None           None
# 6   None                 None      None           None
# 7   None                 None      None           None
# 8   None                 None      None           None
# 9   None                 None      None           None
# 10  None                 None      None           None
# 11  None                 None      None           None
# 12  None                 None      None           None
# 13  None                 None      None           None
# 14  None                 None      None           None
# 15  None                 None      None           None
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-8993d07d-92e8-42a1-88c7-1d3a27320809" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8993d07d-92e8-42a1-88c7-1d3a27320809">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 973145156531.explainer.xml to 973145156531.explainer.xml
# User uploaded file "973145156531.explainer.xml" with length 22774 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('973145156531.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df3 = pd.DataFrame(data).T  # Write in DF and transpose it
df3.columns = cols  # Update column names
print(df3)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to calcul...
# 1   None  ...  A geometric sequence is a sequence that has a ...
# 2   None  ...  For instance, the following sequence is geomet...
# 3   None  ...  This sequence has a common ratio of 3 since ea...
# 4   None  ...  If we define the first term in the general geo...
# 5   None  ...                We now notice that the exponent of
# 6   None  ...  Look at what happens when we divide a term by ...
# 7   None  ...  No matter which pair of terms we choose, their...
# 8   None  ...                             Let’s generalize this.
# 9   None  ...                                           \n
# 10  None  ...                                           \n
# 11  None  ...  Now, let’s go  back to our earlier example of ...
# 12  None  ...                We notice that as the term number,
# 13  None  ...  This is not always the case though. In fact, s...
# ...

# %%
df3
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to calcul...
# 1   None  ...  A geometric sequence is a sequence that has a ...
# 2   None  ...  For instance, the following sequence is geomet...
# 3   None  ...  This sequence has a common ratio of 3 since ea...
# 4   None  ...  If we define the first term in the general geo...
# 5   None  ...                We now notice that the exponent of
# 6   None  ...  Look at what happens when we divide a term by ...
# 7   None  ...  No matter which pair of terms we choose, their...
# 8   None  ...                             Let’s generalize this.
# 9   None  ...                                           \n
# 10  None  ...                                           \n
# 11  None  ...  Now, let’s go  back to our earlier example of ...
# 12  None  ...                We notice that as the term number,
# 13  None  ...  This is not always the case though. In fact, s...
# ...

# %%
f3=df3.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f3
# Out:
#    title  seo_meta_description source_id developer_name
# 0   None                   NaN      None           None
# 1   None                   NaN      None           None
# 2   None                   NaN      None           None
# 3   None                   NaN      None           None
# 4   None                   NaN      None           None
# 5   None                   NaN      None           None
# 6   None                   NaN      None           None
# 7   None                   NaN      None           None
# 8   None                   NaN      None           None
# 9   None                   NaN      None           None
# 10  None                   NaN      None           None
# 11  None                   NaN      None           None
# 12  None                   NaN      None           None
# 13  None                   NaN      None           None
# 14  None                   NaN      None           None
# 15  None                   NaN      None           None
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-223bf66c-5638-4d28-b80c-3980f4bfc29b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-223bf66c-5638-4d28-b80c-3980f4bfc29b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 974125905106.explainer.xml to 974125905106.explainer.xml
# User uploaded file "974125905106.explainer.xml" with length 26602 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('974125905106.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df4 = pd.DataFrame(data).T  # Write in DF and transpose it
df4.columns = cols  # Update column names
print(df4)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to find g...
# 1   None  ...  In many cases, we associate the mean of two nu...
# 2   None  ...                                           \n
# 3   None  ...  We note that we cannot take the geometric mean...
# 4   None  ...                                              When
# 5   None  ...                                               None
# 6   None  ...           The rectangle on the left side has area
# 7   None  ...                 Thus, the square with side length
# 8   None  ...  We can also understand the geometric mean of t...
# 9   None  ...  When we draw a number line with these terms, w...
# 10  None  ...                                               None
# 11  None  ...  Taking the geometric mean of the first and thi...
# 12  None  ...  In other words, the second term of the geometr...
# 13  None  ...  Hence, the fourth term, 24, is the geometric m...
# ...

# %%
df4
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to find g...
# 1   None  ...  In many cases, we associate the mean of two nu...
# 2   None  ...                                           \n
# 3   None  ...  We note that we cannot take the geometric mean...
# 4   None  ...                                              When
# 5   None  ...                                               None
# 6   None  ...           The rectangle on the left side has area
# 7   None  ...                 Thus, the square with side length
# 8   None  ...  We can also understand the geometric mean of t...
# 9   None  ...  When we draw a number line with these terms, w...
# 10  None  ...                                               None
# 11  None  ...  Taking the geometric mean of the first and thi...
# 12  None  ...  In other words, the second term of the geometr...
# 13  None  ...  Hence, the fourth term, 24, is the geometric m...
# ...

# %%
f4=df4.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f4
# Out:
#    title seo_meta_description source_id developer_name
# 0   None                 None      None           None
# 1   None                 None      None           None
# 2   None                 None      None           None
# 3   None                 None      None           None
# 4   None                 None      None           None
# 5   None                 None      None           None
# 6   None                 None      None           None
# 7   None                 None      None           None
# 8   None                 None      None           None
# 9   None                 None      None           None
# 10  None                 None      None           None
# 11  None                 None      None           None
# 12  None                 None      None           None
# 13  None                 None      None           None
# 14  None                 None      None           None
# 15  None                 None      None           None
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-6c2178c5-6b8e-429d-b409-86922cb10061" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c2178c5-6b8e-429d-b409-86922cb10061">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 979165921053.explainer.xml to 979165921053.explainer.xml
# User uploaded file "979165921053.explainer.xml" with length 27956 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('979165921053.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df5 = pd.DataFrame(data).T  # Write in DF and transpose it
df5.columns = cols  # Update column names
print(df5)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to constr...
# 1   None  ...  We can quantify the equilibrium that exists be...
# 2   None  ...                                           \n
# 3   None  ...  In its simplest form, the equilibrium constant...
# 4   None  ...  If we extend this to the general equation\n
# 5   None  ...  Remember that, in chemistry, we use square bra...
# 6   None  ...                        When writing equations for
# 7   None  ...  We can see that the concentration of nitrogen ...
# 8   None  ...                                           \n
# 9   None  ...                                           \n
# 10  None  ...  It is important to note that some questions ma...
# 11  None  ...                                           \n
# 12  None  ...  At higher levels, the discussion of a topic kn...
# 13  None  ...              However, in certain cases, units for
# ...

# %%
df5
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to constr...
# 1   None  ...  We can quantify the equilibrium that exists be...
# 2   None  ...                                           \n
# 3   None  ...  In its simplest form, the equilibrium constant...
# 4   None  ...  If we extend this to the general equation\n
# 5   None  ...  Remember that, in chemistry, we use square bra...
# 6   None  ...                        When writing equations for
# 7   None  ...  We can see that the concentration of nitrogen ...
# 8   None  ...                                           \n
# 9   None  ...                                           \n
# 10  None  ...  It is important to note that some questions ma...
# 11  None  ...                                           \n
# 12  None  ...  At higher levels, the discussion of a topic kn...
# 13  None  ...              However, in certain cases, units for
# ...

# %%
f5=df5.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f5
# Out:
#    title seo_meta_description source_id developer_name
# 0   None                 None      None           None
# 1   None                 None      None           None
# 2   None                 None      None           None
# 3   None                 None      None           None
# 4   None                 None      None           None
# 5   None                 None      None           None
# 6   None                 None      None           None
# 7   None                 None      None           None
# 8   None                 None      None           None
# 9   None                 None      None           None
# 10  None                 None      None           None
# 11  None                 None      None           None
# 12  None                 None      None           None
# 13  None                 None      None           None
# 14  None                 None      None           None
# 15  None                 None      None           None
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-501cb76b-a85a-4aaa-aa5b-b6c7ab7c1a03" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-501cb76b-a85a-4aaa-aa5b-b6c7ab7c1a03">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 980162532502.explainer.xml to 980162532502.explainer.xml
# User uploaded file "980162532502.explainer.xml" with length 34159 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('980162532502.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df6 = pd.DataFrame(data).T  # Write in DF and transpose it
df6.columns = cols  # Update column names
print(df6)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to define...
# 1   None  ...  The composition of a molecule can be expressed...
# 2   None  ...                                           \n
# 3   None  ...  The ratio of carbon atoms to hydrogen atoms to...
# 4   None  ...                                           \n
# 5   None  ...  Empirical formulas are also used to represent ...
# 6   None  ...                                           \n
# 7   None  ...  We can easily determine the empirical formula ...
# 8   None  ...                                           \n
# 9   None  ...  It is possible for the empirical formula and m...
# 10  None  ...  Empirical formulas are often derived from expe...
# 11  None  ...                                           \n
# 12  None  ...  Let us examine how to determine the empirical ...
# 13  None  ...      This gives us a ratio of carbon to oxygen of
# ...

# %%
df6
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to define...
# 1   None  ...  The composition of a molecule can be expressed...
# 2   None  ...                                           \n
# 3   None  ...  The ratio of carbon atoms to hydrogen atoms to...
# 4   None  ...                                           \n
# 5   None  ...  Empirical formulas are also used to represent ...
# 6   None  ...                                           \n
# 7   None  ...  We can easily determine the empirical formula ...
# 8   None  ...                                           \n
# 9   None  ...  It is possible for the empirical formula and m...
# 10  None  ...  Empirical formulas are often derived from expe...
# 11  None  ...                                           \n
# 12  None  ...  Let us examine how to determine the empirical ...
# 13  None  ...      This gives us a ratio of carbon to oxygen of
# ...

# %%
f6=df6.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f6
# Out:
#    title seo_meta_description source_id developer_name
# 0   None                 None      None           None
# 1   None                 None      None           None
# 2   None                 None      None           None
# 3   None                 None      None           None
# 4   None                 None      None           None
# 5   None                 None      None           None
# 6   None                 None      None           None
# 7   None                 None      None           None
# 8   None                 None      None           None
# 9   None                 None      None           None
# 10  None                 None      None           None
# 11  None                 None      None           None
# 12  None                 None      None           None
# 13  None                 None      None           None
# 14  None                 None      None           None
# 15  None                 None      None           None
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-fe3ba915-324a-4aee-88e6-6c6929ae9aa3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fe3ba915-324a-4aee-88e6-6c6929ae9aa3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 985161036067.explainer.xml to 985161036067.explainer.xml
# User uploaded file "985161036067.explainer.xml" with length 19996 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('985161036067.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df7 = pd.DataFrame(data).T  # Write in DF and transpose it
df7.columns = cols  # Update column names
print(df7)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to find t...
# 1   None  ...  The probability of an event is the likelihood ...
# 2   None  ...  When we discuss the likelihood of an event hap...
# 3   None  ...                                               None
# 4   None  ...  The sum of the probabilities of all possible o...
# 5   None  ...  In probability terms, a simple event refers to...
# 6   None  ...  We also need to consider “fairness” when discu...
# 7   None  ...                                           \n
# 8   None  ...  Consider the situation of flipping a fair coin...
# 9   None  ...                                           \n
# 10  None  ...  Commonly in probability, we may use the notation
# 11  None  ...  We can now see how this information can be app...
# 12  None  ...                                           \n
# 13  None  ...  In the following example, we will see how we m...
# ...

# %%
df7
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to find t...
# 1   None  ...  The probability of an event is the likelihood ...
# 2   None  ...  When we discuss the likelihood of an event hap...
# 3   None  ...                                               None
# 4   None  ...  The sum of the probabilities of all possible o...
# 5   None  ...  In probability terms, a simple event refers to...
# 6   None  ...  We also need to consider “fairness” when discu...
# 7   None  ...                                           \n
# 8   None  ...  Consider the situation of flipping a fair coin...
# 9   None  ...                                           \n
# 10  None  ...  Commonly in probability, we may use the notation
# 11  None  ...  We can now see how this information can be app...
# 12  None  ...                                           \n
# 13  None  ...  In the following example, we will see how we m...
# ...

# %%
f7=df7.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f7
# Out:
#    title seo_meta_description source_id developer_name
# 0   None                 None      None           None
# 1   None                 None      None           None
# 2   None                 None      None           None
# 3   None                 None      None           None
# 4   None                 None      None           None
# 5   None                 None      None           None
# 6   None                 None      None           None
# 7   None                 None      None           None
# 8   None                 None      None           None
# 9   None                 None      None           None
# 10  None                 None      None           None
# 11  None                 None      None           None
# 12  None                 None      None           None
# 13  None                 None      None           None
# 14  None                 None      None           None
# 15  None                 None      None           None
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-670a6c08-7222-447f-bcfe-428f09688c4c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-670a6c08-7222-447f-bcfe-428f09688c4c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 985195836913.explainer.xml to 985195836913.explainer.xml
# User uploaded file "985195836913.explainer.xml" with length 28418 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('972198025105.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df8 = pd.DataFrame(data).T  # Write in DF and transpose it
df8.columns = cols  # Update column names
print(df8)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# ...

# %%
df8
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to identi...
# 1   None  ...  Fundamental physical quantities (also called b...
# 2   None  ...  The following is a list of the SI base quantit...
# 3   None  ...  In this explainer, we will only be considering...
# 4   None  ...  The explainer is specifically concerned with h...
# 5   None  ...  Length is measured using an instrument that is...
# 6   None  ...  A ruler is a straight-edged stick with graduat...
# 7   None  ...          The marks on a ruler are usually \n
# 8   None  ...
# 9   None  ...  The maximum length that can be measured by a r...
# 10  None  ...           To measure lengths of less than \n
# 11  None  ...
# 12  None  ...  The length measured by a vernier caliper is th...
# 13  None  ...
# 14  None  ...  The red arrow between the jaws of the caliper ...
# 15  None  ...  The main scale of the caliper is the same as t...
# ...

# %%
f8=df8.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f8
# Out:
#    title seo_meta_description  source_id developer_name
# 0   None                 None        NaN           None
# 1   None                 None        NaN           None
# 2   None                 None        NaN           None
# 3   None                 None        NaN           None
# 4   None                 None        NaN           None
# 5   None                 None        NaN           None
# 6   None                 None        NaN           None
# 7   None                 None        NaN           None
# 8   None                 None        NaN           None
# 9   None                 None        NaN           None
# 10  None                 None        NaN           None
# 11  None                 None        NaN           None
# 12  None                 None        NaN           None
# 13  None                 None        NaN           None
# 14  None                 None        NaN           None
# 15  None                 None        NaN           None
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-2886cad5-b6fd-4a8b-8cfc-a0eb1c66d7af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2886cad5-b6fd-4a8b-8cfc-a0eb1c66d7af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 989130863985.explainer.xml to 989130863985.explainer.xml
# User uploaded file "989130863985.explainer.xml" with length 24995 bytes

# %%
import xml.etree.ElementTree as ET
import pandas as pd

xml_data = open('989130863985.explainer.xml', 'r').read()  # Read file
root = ET.XML(xml_data)  # Parse XML

data = []
cols = []
for i, child in enumerate(root):
    data.append([subchild.text for subchild in child])
    cols.append(child.tag)

df9 = pd.DataFrame(data).T  # Write in DF and transpose it
df9.columns = cols  # Update column names
print(df9)
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to calcul...
# 1   None  ...  Imagine an object that moves at a constant vel...
# 2   None  ...
# 3   None  ...  Since the velocity is constant, the graph show...
# 4   None  ...  The object in the graph above moves at a veloc...
# 5   None  ...  Another question we could ask is “What is the ...
# 6   None  ...  Now imagine an object that moves at a steadily...
# 7   None  ...
# 8   None  ...  Since the velocity is increasing steadily over...
# 9   None  ...             In this case, the initial velocity is
# 10  None  ...  But another way of thinking about this is in t...
# 11  None  ...
# 12  None  ...  The blue region is a rectangle, so its area is...
# 13  None  ...     Since we said that the velocity is increasing
# 14  None  ...                Let’s have a look at some examples.
# 15  None  ...                                           \n
# ...

# %%
df9
# Out:
#    title  ...                                               body
# 0   None  ...  In this explainer, we will learn how to calcul...
# 1   None  ...  Imagine an object that moves at a constant vel...
# 2   None  ...
# 3   None  ...  Since the velocity is constant, the graph show...
# 4   None  ...  The object in the graph above moves at a veloc...
# 5   None  ...  Another question we could ask is “What is the ...
# 6   None  ...  Now imagine an object that moves at a steadily...
# 7   None  ...
# 8   None  ...  Since the velocity is increasing steadily over...
# 9   None  ...             In this case, the initial velocity is
# 10  None  ...  But another way of thinking about this is in t...
# 11  None  ...
# 12  None  ...  The blue region is a rectangle, so its area is...
# 13  None  ...     Since we said that the velocity is increasing
# 14  None  ...                Let’s have a look at some examples.
# 15  None  ...                                           \n
# ...

# %%
f9=df9.reindex(columns=['title', 'seo_meta_description', 'source_id', 'developer_name'])

# %%
f9
# Out:
#    title seo_meta_description source_id  developer_name
# 0   None                 None      None             NaN
# 1   None                 None      None             NaN
# 2   None                 None      None             NaN
# 3   None                 None      None             NaN
# 4   None                 None      None             NaN
# 5   None                 None      None             NaN
# 6   None                 None      None             NaN
# 7   None                 None      None             NaN
# 8   None                 None      None             NaN
# 9   None                 None      None             NaN
# 10  None                 None      None             NaN
# 11  None                 None      None             NaN
# 12  None                 None      None             NaN
# 13  None                 None      None             NaN
# 14  None                 None      None             NaN
# 15  None                 None      None             NaN
# ...

# %% [markdown]
# **Concat DataFrames**

# %%
pdList = [f,f1,f2,f3,f4,f5,f6,f7,f8,f9]  # List of your dataframes
new_df = pd.concat(pdList)

# %%
new_df
# Out:
#    explainer id/name seo_meta_description source_id developer_name title
# 0               None                 None      None           None  None
# 1               None                 None      None           None  None
# 2               None                 None      None           None  None
# 3               None                 None      None           None  None
# 4               None                 None      None           None  None
# ..               ...                  ...       ...            ...   ...
# 27               NaN                  NaN       NaN            NaN   NaN
# 28               NaN                  NaN       NaN            NaN   NaN
# 29               NaN                  NaN       NaN            NaN   NaN
# 30               NaN                  NaN       NaN            NaN   NaN
# 31               NaN                  NaN       NaN            NaN   NaN
#
# [401 rows x 5 columns]

# %%
new_df_1=new_df.drop('title',1)

# %%
new_df_1
# Out:
#    explainer id/name seo_meta_description source_id developer_name
# 0               None                 None      None           None
# 1               None                 None      None           None
# 2               None                 None      None           None
# 3               None                 None      None           None
# 4               None                 None      None           None
# ..               ...                  ...       ...            ...
# 27               NaN                  NaN       NaN            NaN
# 28               NaN                  NaN       NaN            NaN
# 29               NaN                  NaN       NaN            NaN
# 30               NaN                  NaN       NaN            NaN
# 31               NaN                  NaN       NaN            NaN
#
# [401 rows x 4 columns]

# %%
new_df_1_t=new_df_1.T

# %%
new_df_1_t
# Out:
#                         0     1     2     3   ...    28    29    30    31
# explainer id/name     None  None  None  None  ...   NaN   NaN   NaN   NaN
# seo_meta_description  None  None  None  None  ...  None  None  None  None
# source_id             None  None  None  None  ...  None  None  None  None
# developer_name        None  None  None  None  ...   NaN   NaN   NaN   NaN
#
# [4 rows x 401 columns]

# %%
new_df_T=new_df.drop(df.columns[[4]],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-87fc495b6616> in <module>()
# ----> 1 new_df_T=new_df.drop(df.columns[[4]],axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
new_df_T
# Out:
#    explainer id/name seo_meta_description source_id explainer id/name
# 0               None                 None      None              None
# 1               None                 None      None              None
# 2               None                 None      None              None
# 3               None                 None      None              None
# 4               None                 None      None              None
# ..               ...                  ...       ...               ...
# 27               NaN                  NaN       NaN               NaN
# 28               NaN                  NaN       NaN               NaN
# 29               NaN                  NaN       NaN               NaN
# 30               NaN                  NaN       NaN               NaN
# 31               NaN                  NaN       NaN               NaN
#
# [401 rows x 4 columns]

# %%
new_df_T
# Out:
#                                                                      0   ...        37
# title                                                              None  ...      None
# seo_meta_description                                               None  ...      None
# source_id                                                          None  ...      None
# developer_name                                                     None  ...      None
# developer_email                                                    None  ...      None
# dictionary                                                     \n        ...      None
# body                  In this explainer, we will learn how to solve ...  ...  \n
#
# [7 rows x 38 columns]
